# %%
from IPython.display import Image

# %% [markdown]
# O algoritimo de Perceptron é um algoritimo de machine learning usado em classificações binárias, ou seja, pode ser treinado para separar os dados em duas categorias.
#
# Além de estar restrito a classificação binária, as variáveis de entrada (features) prescisam ser lineramente separáveis entre si para que o modelo possa funcionar bem.
#
# Segue o exemplo bidimencional de variáveis linearmente separáveis e não linearmente separáveis:

# %%
Image(filename='./Imagens/img_001.png', width=600)

# %% [markdown]
# A seguir vamos representar o conjunto de hipótezes em que esse algoritmo se baseia.

# %%
Image(filename='./Imagens/img_002.png', width=800)

# %% [markdown]
# A resolução desse problema consiste em descobrir qual vetor w apresenta os melhores resultados. Dessa forma, podemos utilizar um algoritmo de busca para encontrar um valor aproximado para w.
#
# Partindo de um vetor w aleatório, podemos iterar sobre os dados de entrada e acada iteração testar se o vetor w atual acerta ou erra os valores target de y. Caso acerte, devemos mover o vetor w para mais perto do vetor x e, caso contrário, se afastar do vetor x. O quanto vamos aproximar ou afastar é definido como taxa de aprendizagem eta.

# %%
Image(filename='./Imagens/img_003.png', width=500)

# %% [markdown]
# Dessa forma, já possuímos ferramentas suficientes para escrever nosso algoritmo.
